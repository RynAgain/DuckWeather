# %%
from WetDuck import Duck as wd
import WetDuck
import json

city = 'Austin'

mycity = wd(city)

# %%
mycity.data
# Out:
# {'latitude': 30.2643,
#  'longitude': -97.7475,
#  'timezone': 'America/Chicago',
#  'currently': {'time': 1667473775,
#   'summary': 'Overcast',
#   'icon': 'cloudy',
#   'nearestStormDistance': 21,
#   'nearestStormBearing': 9,
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 70.64,
#   'apparentTemperature': 71.86,
#   'dewPoint': 69.1,
#   'humidity': 0.95,
#   'pressure': 1017.5,
#   'windSpeed': 6.53,
#   'windGust': 16.12,
#   'windBearing': 169,
#   'cloudCover': 0.98,
#   'uvIndex': 0,
#   'visibility': 9.646,
#   'ozone': 253.2},
#  'minutely': {'summary': 'Overcast for the hour.',
#   'icon': 'cloudy',
#   'data': [{'time': 1667473740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1667473800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1667473860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1667473920, 'precipIntensity': 0, 'precipProbability': 0},
# ...

# %%
mycity.get_data('Sydney')
mycity.data
# Out:
# {'latitude': -33.8727,
#  'longitude': 151.2057,
#  'timezone': 'Australia/Sydney',
#  'currently': {'time': 1667473641,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0011,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 58.47,
#   'apparentTemperature': 58.47,
#   'dewPoint': 49.11,
#   'humidity': 0.71,
#   'pressure': 1023,
#   'windSpeed': 7.66,
#   'windGust': 11.5,
#   'windBearing': 151,
#   'cloudCover': 0.62,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 308.9},
#  'hourly': {'summary': 'Mostly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1667473200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 58.55,
#     'apparentTemperature': 58.55,
#     'dewPoint': 49.07,
#     'humidity': 0.71,
#     'pressure': 1022.9,
# ...

# %%
mycity.update()
mycity.data
# Out:
# {'latitude': -33.8727,
#  'longitude': 151.2057,
#  'timezone': 'Australia/Sydney',
#  'currently': {'time': 1667473586,
#   'summary': 'Mostly Cloudy',
#   'icon': 'partly-cloudy-night',
#   'precipIntensity': 0.0011,
#   'precipProbability': 0.05,
#   'precipType': 'rain',
#   'temperature': 58.48,
#   'apparentTemperature': 58.48,
#   'dewPoint': 49.1,
#   'humidity': 0.71,
#   'pressure': 1023,
#   'windSpeed': 7.68,
#   'windGust': 11.54,
#   'windBearing': 151,
#   'cloudCover': 0.62,
#   'uvIndex': 0,
#   'visibility': 10,
#   'ozone': 308.9},
#  'hourly': {'summary': 'Mostly cloudy throughout the day.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1667473200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 58.55,
#     'apparentTemperature': 58.55,
#     'dewPoint': 49.07,
#     'humidity': 0.71,
#     'pressure': 1022.9,
# ...

# %%
mycity.now()
# Out:
# {'time': 1667473586,
#  'summary': 'Mostly Cloudy',
#  'icon': 'partly-cloudy-night',
#  'precipIntensity': 0.0011,
#  'precipProbability': 0.05,
#  'precipType': 'rain',
#  'temperature': 58.48,
#  'apparentTemperature': 58.48,
#  'dewPoint': 49.1,
#  'humidity': 0.71,
#  'pressure': 1023,
#  'windSpeed': 7.68,
#  'windGust': 11.54,
#  'windBearing': 151,
#  'cloudCover': 0.62,
#  'uvIndex': 0,
#  'visibility': 10,
#  'ozone': 308.9}

# %%
z = list(mycity.data)
z
# Out:
# ['latitude',
#  'longitude',
#  'timezone',
#  'currently',
#  'hourly',
#  'daily',
#  'flags',
#  'offset']

# %%
for i in z:
    print(mycity.data[i])
# Out:
# -33.8727
# 151.2057
# Australia/Sydney
# {'time': 1667473586, 'summary': 'Mostly Cloudy', 'icon': 'partly-cloudy-night', 'precipIntensity': 0.0011, 'precipProbability': 0.05, 'precipType': 'rain', 'temperature': 58.48, 'apparentTemperature': 58.48, 'dewPoint': 49.1, 'humidity': 0.71, 'pressure': 1023, 'windSpeed': 7.68, 'windGust': 11.54, 'windBearing': 151, 'cloudCover': 0.62, 'uvIndex': 0, 'visibility': 10, 'ozone': 308.9}
# ...
